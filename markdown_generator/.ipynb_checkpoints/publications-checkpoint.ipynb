# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a TSV of publications with metadata and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)). The core python code is also in `publications.py`. Run either from the `markdown_generator` folder after replacing `publications.tsv` with one containing your data.
#
# TODO: Make this work with BibTex and other databases of citations, rather than Stuart's non-standard TSV format and citation style.

# %% [markdown]
# ## Data format
#
# The TSV needs to have the following columns: pub_date, title, venue, excerpt, citation, site_url, and paper_url, with a header at the top.
#
# - `excerpt` and `paper_url` can be blank, but the others must have values.
# - `pub_date` must be formatted as YYYY-MM-DD.
# - `url_slug` will be the descriptive part of the .md file and the permalink URL for the page about the paper. The .md file will be `YYYY-MM-DD-[url_slug].md` and the permalink will be `https://[yourdomain]/publications/YYYY-MM-DD-[url_slug]`
#
# This is how the raw file looks (it doesn't look pretty, use a spreadsheet or other program to edit and create).

# %%
# !cat publications.tsv.old
# Out:
# pub_date	title	venue	excerpt	citation	url_slug	paper_url	slides_url
# 2009-10-01	Paper Title Number 1	Journal 1	This paper is about the number 1. The number 2 is left for future work.	Your Name, You. (2009). "Paper Title Number 1." <i>Journal 1</i>. 1(1).	paper-title-number-1	http://academicpages.github.io/files/paper1.pdf	http://academicpages.github.io/files/slides1.pdf
# 2010-10-01	Paper Title Number 2	Journal 1	This paper is about the number 2. The number 3 is left for future work.	Your Name, You. (2010). "Paper Title Number 2." <i>Journal 1</i>. 1(2).	paper-title-number-2	http://academicpages.github.io/files/paper2.pdf	http://academicpages.github.io/files/slides2.pdf
# 2015-10-01	Paper Title Number 3	Journal 1	This paper is about the number 3. The number 4 is left for future work.	Your Name, You. (2015). "Paper Title Number 3." <i>Journal 1</i>. 1(3).	paper-title-number-3	http://academicpages.github.io/files/paper3.pdf	http://academicpages.github.io/files/slides3.pdf

# %%
from scholarly import scholarly
import csv

# Define the target author and output file
author_name = "Reid T. Powell"
output_file = "publications.tsv"

# %%
# Search for the author
search_query = scholarly.search_author(author_name)
author = next(search_query, None)

if author:
    # Fill in the author's details
    author = scholarly.fill(author)
    publications = author.get('publications', [])
else:
    print(f"Author '{author_name}' not found.")
    publications = []

# %%
publications
# Out:
#     pub_date                                              title  \
# 0       2015  ATM functions at the peroxisome to induce pexo...
# 1       2016  Dual chromatin and cytoskeletal remodeling by ...
# 2       2018  PanCancer insights from The Cancer Genome Atla...
# 3       2019  Bacteria-to-human protein networks reveal orig...
# 4       2014  Defining estrogenic mechanisms of bisphenol A ...
# ..       ...                                                ...
# 65      2020  Abstract P3-03-08: Identification of drugs tha...
# 66      2019  Single cell transcriptomic profiling of ex viv...
# 67      2018  Extracting Biological Knowledge from High Thro...
# 68      2017  The role of hepatocyte nuclear factor 1 homeob...
# 69      1991  A twin-tub CMOS using self-aligned channel-sto...
#
#                   venue                                            excerpt  \
# 0   Nature cell biology  Peroxisomes are highly metabolic, autonomously...
# 1                  Cell  Posttranslational modifications (PTMs) of tubu...
# 2                   NaN  The Cancer Genome Atlas (TCGA) represents one ...
# 3                  Cell  DNA damage provokes mutations and cancer and r...
# 4   Chemistry & biology  Environmental exposures to chemically heteroge...
# ..                  ...                                                ...
# 65      Cancer Research  Background: P53 is the most commonly mutated p...
# 66      Cancer Research  By 2030, pancreatic ductal adenocarcinoma (PDA...
# 67                  NaN  High throughput drug screening has greatly pro...
# 68   Annals of Oncology  Background: ChRCC is characterized by dramatic...
# 69                  NaN  Describes a simplified twin-tub process for hi...
#
#                                              citation  \
# 0   Reid T. Powell (2015). ATM functions at the pe...
# 1   Reid T. Powell (2016). Dual chromatin and cyto...
# 2   Reid T. Powell (2018). PanCancer insights from...
# 3   Reid T. Powell (2019). Bacteria-to-human prote...
# 4   Reid T. Powell (2014). Defining estrogenic mec...
# ..                                                ...
# 65  Reid T. Powell (2020). Abstract P3-03-08: Iden...
# 66  Reid T. Powell (2019). Single cell transcripto...
# 67  Reid T. Powell (2018). Extracting Biological K...
# 68  Reid T. Powell (2017). The role of hepatocyte ...
# 69  Reid T. Powell (1991). A twin-tub CMOS using s...
#
#                                              url_slug  \
# 0   2015-ATM functions at the peroxisome to induce...
# 1   2016-Dual chromatin and cytoskeletal remodelin...
# 2   2018-PanCancer insights from The Cancer Genome...
# 3   2019-Bacteria-to-human protein networks reveal...
# 4   2014-Defining estrogenic mechanisms of bisphen...
# ..                                                ...
# 65  2020-Abstract P3-03-08: Identification of drug...
# 66  2019-Single cell transcriptomic profiling of e...
# 67  2018-Extracting Biological Knowledge from High...
# 68  2017-The role of hepatocyte nuclear factor 1 h...
# 69  1991-A twin-tub CMOS using self-aligned channe...
#
#                                             paper_url  slides_url
# 0             https://www.nature.com/articles/ncb3230         NaN
# 1   https://www.cell.com/cell/fulltext/S0092-8674(...         NaN
# 2   https://pathsocjournals.onlinelibrary.wiley.co...         NaN
# 3   https://www.cell.com/cell/fulltext/S0092-8674(...         NaN
# 4   https://www.cell.com/ccbio/fulltext/S1074-5521...         NaN
# ..                                                ...         ...
# 65  https://aacrjournals.org/cancerres/article/80/...         NaN
# 66  https://aacrjournals.org/cancerres/article-abs...         NaN
# 67  https://search.proquest.com/openview/4aecf1bf1...         NaN
# 68  https://www.annalsofoncology.org/article/S0923...         NaN
# 69  https://www.computer.org/csdl/proceedings-arti...         NaN
#
# [70 rows x 8 columns]

# %%
# Define the TSV headers
headers = [
    "pub_date", "title", "venue", "excerpt",
    "citation", "url_slug", "paper_url", "slides_url"
]

# Process each publication and write to the TSV file
with open(output_file, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.DictWriter(file, fieldnames=headers, delimiter='\t')
    writer.writeheader()

    for pub in publications:
        # Fill in the publication details
        pub = scholarly.fill(pub)

        # Extract relevant information
        pub_date = pub.get('bib', {}).get('pub_year', '')
        title = pub.get('bib', {}).get('title', '')
        venue = pub.get('bib', {}).get('journal', '')
        excerpt = pub.get('bib', {}).get('abstract', '')
        citation = f"{author_name} ({pub_date}). {title}. {venue}."
        url_slug = f"{pub_date}-{title}"
        paper_url = pub.get('pub_url', '')
        slides_url = ''  # Slides URL not available

        # Write the row to the TSV file
        writer.writerow({
            "pub_date": pub_date,
            "title": title,
            "venue": venue,
            "excerpt": excerpt,
            "citation": citation,
            "url_slug": url_slug,
            "paper_url": paper_url,
            "slides_url": slides_url
        })

# %% [markdown]
# ## Import pandas
#
# We are using the very handy pandas library for dataframes.

# %%
import pandas as pd

# %% [markdown]
# ## Import TSV
#
# Pandas makes this easy with the read_csv function. We are using a TSV, so we specify the separator as a tab, or `\t`.
#
# I found it important to put this data in a tab-separated values format, because there are a lot of commas in this kind of data and comma-separated values can get messed up. However, you can modify the import statement, as pandas also has read_excel(), read_json(), and others.

# %%
publications = pd.read_csv("publications.tsv", sep="\t", header=0)
publications
# Out:
#     pub_date                                              title  \
# 0       2014  Defining estrogenic mechanisms of bisphenol A ...
# 1       2015  ATM functions at the peroxisome to induce pexo...
# 2       2016  Dual chromatin and cytoskeletal remodeling by ...
# 3       2016  Methylated α-tubulin antibodies recognize a ne...
# 4       2017  Identification of histological correlates of o...
# ..       ...                                                ...
# 61      2024  Chemical genetic analysis of enoxolone inhibit...
# 62      2024  Inhibition of GPX4 Induces the Death of p53-Mu...
# 63      2024  Cystic fibrosis cell models for high-throughpu...
# 64      2024  PDX models of TNBC established from pre-and po...
# 65      2024  Enhancing efficacy of the MEK inhibitor tramet...
#
#                                venue  \
# 0                Chemistry & biology
# 1                Nature cell biology
# 2                               Cell
# 3                               MAbs
# 4   Journal of pathology informatics
# ..                               ...
# 61   Journal of Biological Chemistry
# 62                                 -
# 63        Journal of Cystic Fibrosis
# 64                   Cancer Research
# 65                           bioRxiv
#
#                                               excerpt  \
# 0   Environmental exposures to chemically heteroge...
# 1   Peroxisomes are highly metabolic, autonomously...
# 2   Posttranslational modifications (PTMs) of tubu...
# 3   Posttranslational modifications (PTMs) on micr...
# 4   Background: Glioma, the most common primary br...
# ..                                                ...
# 61  Toxins TcdA and TcdB are the main virulence fa...
# 62  BackgroundTriple-negative breast cancer (TNBC)...
# 63  Cystic fibrosis (CF) is a single-gene disorder...
# 64  Chemotherapy, along with the PD1 inhibitor pem...
# 65  Background KRAS is frequently mutated in the t...
#
#                                              citation             url_slug  \
# 0   Reid T. Powell (2014). Defining estrogenic mec...   2014-Publication-1
# 1   Reid T. Powell (2015). ATM functions at the pe...   2014-Publication-2
# 2   Reid T. Powell (2016). Dual chromatin and cyto...   2014-Publication-3
# 3   Reid T. Powell (2016). Methylated α-tubulin an...   2014-Publication-4
# 4   Reid T. Powell (2017). Identification of histo...   2014-Publication-5
# ..                                                ...                  ...
# 61  Reid T. Powell (2024). Chemical genetic analys...  2014-Publication-62
# 62  Reid T. Powell (2024). Inhibition of GPX4 Indu...  2014-Publication-63
# 63  Reid T. Powell (2024). Cystic fibrosis cell mo...  2014-Publication-64
# 64  Reid T. Powell (2024). PDX models of TNBC esta...  2014-Publication-65
# 65  Reid T. Powell (2024). Enhancing efficacy of t...  2014-Publication-66
#
#                                             paper_url  slides_url
# 0   https://www.cell.com/ccbio/fulltext/S1074-5521...         NaN
# 1             https://www.nature.com/articles/ncb3230         NaN
# 2   https://www.cell.com/cell/fulltext/S0092-8674(...         NaN
# 3   https://www.tandfonline.com/doi/abs/10.1080/19...         NaN
# 4   https://www.sciencedirect.com/science/article/...         NaN
# ..                                                ...         ...
# 61  https://www.sciencedirect.com/science/article/...         NaN
# 62  https://www.researchsquare.com/article/rs-4864...         NaN
# 63  https://www.sciencedirect.com/science/article/...         NaN
# 64  https://aacrjournals.org/cancerres/article/84/...         NaN
# 65  https://www.biorxiv.org/content/10.1101/2024.0...         NaN
#
# [66 rows x 8 columns]

# %% [markdown]
# ## Escape special characters
#
# YAML is very picky about how it takes a valid string, so we are replacing single and double quotes (and ampersands) with their HTML encoded equivilents. This makes them look not so readable in raw format, but they are parsed and rendered nicely.

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %% [markdown]
# ## Creating the markdown files
#
# This is where the heavy lifting is done. This loops through all the rows in the TSV dataframe, then starts to concatentate a big string (```md```) that contains the markdown for each type. It does the YAML metadata first, then does the description for the individual page.

# %%
import os
for row, item in publications.iterrows():
    
    md_filename = str(item.pub_date) + "-" + item.url_slug + ".md"
    html_filename = str(item.pub_date) + "-" + item.url_slug
    year = item.pub_date
    
    ## YAML variables
    
    md = "---\ntitle: \""   + item.title + '"\n'
    
    md += """collection: publications\n"""
    
    md += """category: manuscripts"""
    
    md += """\npermalink: /publication/""" + html_filename
    
    if len(str(item.excerpt)) > 5:
        md += "\nexcerpt: '" + html_escape(item.excerpt) + "'"
    
    md += "\ndate: " + str(item.pub_date) 
    
    md += "\nvenue: '" + html_escape(item.venue) + "'"
    
    if len(str(item.slides_url)) > 5:
        md += "\nslidesurl: '" + item.slides_url + "'"

    if len(str(item.paper_url)) > 5:
        md += "\npaperurl: '" + item.paper_url + "'"
    
    md += "\ncitation: '" + html_escape(item.citation) + "'"
    
    md += "\n---"
    
    ## Markdown description for individual page
        
    if len(str(item.excerpt)) > 5:
        md += "\n" + html_escape(item.excerpt) + "\n"

    if len(str(item.slides_url)) > 5:
        md += "\n[Download slides here](" + item.slides_url + ")\n" 

    if len(str(item.paper_url)) > 5:
        md += "\n[Download paper here](" + item.paper_url + ")\n" 
        
    md += "\nRecommended citation: " + item.citation
    
    md_filename = os.path.basename(md_filename)
       
    with open("../_publications/" + md_filename, 'w') as f:
        f.write(md)

# %% [markdown]
# These files are in the publications directory, one directory below where we're working from.

# %%
# !ls ../_publications/
# Out:
# 2009-10-01-paper-title-number-1.md  2015-10-01-paper-title-number-3.md
# 2010-10-01-paper-title-number-2.md  2024-02-17-paper-title-number-4.md

# %%
# !cat ../_publications/2009-10-01-paper-title-number-1.md
# Out:
# ---
# title: "Paper Title Number 1"
# collection: publications
# permalink: /publication/2009-10-01-paper-title-number-1
# excerpt: 'This paper is about the number 1. The number 2 is left for future work.'
# date: 2009-10-01
# venue: 'Journal 1'
# slidesurl: 'http://academicpages.github.io/files/slides1.pdf'
# paperurl: 'http://academicpages.github.io/files/paper1.pdf'
# citation: 'Your Name, You. (2009). &quot;Paper Title Number 1.&quot; <i>Journal 1</i>. 1(1).'
# ---
# This paper is about the number 1. The number 2 is left for future work.
#
# [Download slides here](http://academicpages.github.io/files/slides1.pdf)
#
# [Download paper here](http://academicpages.github.io/files/paper1.pdf)
#
# Recommended citation: Your Name, You. (2009). "Paper Title Number 1." <i>Journal 1</i>. 1(1).
