# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a set of bibtex of publications and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)).
#
# The core python code is also in `pubsFromBibs.py`.
# Run either from the `markdown_generator` folder after replacing updating the publist dictionary with:
# * bib file names
# * specific venue keys based on your bib file preferences
# * any specific pre-text for specific files
# * Collection Name (future feature)
#
# TODO: Make this work with other databases of citations,
# TODO: Merge this with the existing TSV parsing solution

# %%
from pybtex.database.input import bibtex
import pybtex.database.input.bibtex 
from time import strptime
import string
import html
import os
import re

# %%
#todo: incorporate different collection types rather than a catch all publications, requires other changes to template
publist = {
    "proceeding": {
        "file" : "proceedings.bib",
        "venuekey": "booktitle",
        "venue-pretext": "In the proceedings of ",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
        
    },
    "journal":{
        "file": "pubs.bib",
        "venuekey" : "journal",
        "venue-pretext" : "",
        "catagory" : "manuscripts",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
    } 
}

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %%
from pybtex import errors
errors.set_strict_mode(False)

for pubsource in publist:
    parser = bibtex.Parser()
    bibdata = parser.parse_file(publist[pubsource]["file"])

    #loop through the individual references in a given bibtex file
    for bib_id in bibdata.entries:
        #reset default date
        pub_year = "1900"
        pub_month = "01"
        pub_day = "01"
        
        b = bibdata.entries[bib_id].fields
        
        try:
            pub_year = f'{b["year"]}'

            #todo: this hack for month and day needs some cleanup
            if "month" in b.keys(): 
                if(len(b["month"])<3):
                    pub_month = "0"+b["month"]
                    pub_month = pub_month[-2:]
                elif(b["month"] not in range(12)):
                    tmnth = strptime(b["month"][:3],'%b').tm_mon   
                    pub_month = "{:02d}".format(tmnth) 
                else:
                    pub_month = str(b["month"])
            if "day" in b.keys(): 
                pub_day = str(b["day"])

                
            pub_date = pub_year+"-"+pub_month+"-"+pub_day
            
            #strip out {} as needed (some bibtex entries that maintain formatting)
            clean_title = b["title"].replace("{", "").replace("}","").replace("\\","").replace(" ","-")    

            url_slug = re.sub("\\[.*\\]|[^a-zA-Z0-9_-]", "", clean_title)
            url_slug = url_slug.replace("--","-")

            md_filename = (str(pub_date) + "-" + url_slug + ".md").replace("--","-")
            html_filename = (str(pub_date) + "-" + url_slug).replace("--","-")

            #Build Citation from text
            citation = ""

            #citation authors - todo - add highlighting for primary author?
            for author in bibdata.entries[bib_id].persons["author"]:
                citation = citation+" "+author.first_names[0]+" "+author.last_names[0]+", "

            #citation title
            citation = citation + "\"" + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + ".\""

            #add venue logic depending on citation type
            venue = publist[pubsource]["venue-pretext"]+b[publist[pubsource]["venuekey"]].replace("{", "").replace("}","").replace("\\","")

            citation = citation + " " + html_escape(venue)
            citation = citation + ", " + pub_year + "."

            
            ## YAML variables
            md = "---\ntitle: \""   + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + '"\n'
            
            md += """collection: """ +  publist[pubsource]["collection"]["name"] + '"\n'

            md += "category: manuscripts\n"

            md += """\npermalink: """ + publist[pubsource]["collection"]["permalink"]  + html_filename
            
            note = False
            if "note" in b.keys():
                if len(str(b["note"])) > 5:
                    md += "\nexcerpt: '" + html_escape(b["note"]) + "'"
                    note = True

            md += "\ndate: " + str(pub_date) 

            md += "\nvenue: '" + html_escape(venue) + "'"
            
            url = False
            if "url" in b.keys():
                if len(str(b["url"])) > 5:
                    md += "\npaperurl: '" + b["url"] + "'"
                    url = True

            md += "\ncitation: '" + html_escape(citation) + "'"

            md += "\n---"

            
            ## Markdown description for individual page
            if note:
                md += "\n" + html_escape(b["note"]) + "\n"

            if url:
                md += "\n[Access paper here](" + b["url"] + "){:target=\"_blank\"}\n" 
            else:
                md += "\nUse [Google Scholar](https://scholar.google.com/scholar?q="+html.escape(clean_title.replace("-","+"))+"){:target=\"_blank\"} for full citation"

            md_filename = os.path.basename(md_filename)

            with open("../_publications/" + md_filename, 'w', encoding="utf-8") as f:
                f.write(md)
            print(f'SUCESSFULLY PARSED {bib_id}: \"', b["title"][:60],"..."*(len(b['title'])>60),"\"")
        # field may not exist for a reference
        except KeyError as e:
            print(f'WARNING Missing Expected Field {e} from entry {bib_id}: \"', b["title"][:30],"..."*(len(b['title'])>30),"\"")
            continue
# Out:
# WARNING Missing Expected Field 'booktitle' from entry de_Groot_2022: " Combined inhibition of {HMGCoA ... "
# WARNING Missing Expected Field 'booktitle' from entry Powell_2022: " {deepOrganoid}: A brightfield  ... "
# WARNING Missing Expected Field 'booktitle' from entry Shah_2021: " Mammary-specific expression of ... "
# WARNING Missing Expected Field 'booktitle' from entry Zhao_2021: " Morphological screening of mes ... "
# WARNING Missing Expected Field 'booktitle' from entry Handley_2021: " Rational Combination of {CRM}1 ... "
# WARNING Missing Expected Field 'booktitle' from entry Chowdhury_2021: " Therapeutically actionable sig ... "
# WARNING Missing Expected Field 'booktitle' from entry Bolt_2021: " Endocrine disrupting chemicals ... "
# WARNING Missing Expected Field 'booktitle' from entry Henderson_2021: " A High-Throughput Approach to  ... "
# WARNING Missing Expected Field 'booktitle' from entry 1a8261afcb35e975c081382a2d99e23787366d37579903bccbbaa04e3803d848: " {Pharmacologic profiling of pa ... "
# WARNING Missing Expected Field 'booktitle' from entry Powell2019: " Bacteria-to-Human Protein Netw ... "
# WARNING Missing Expected Field 'booktitle' from entry 68611bd12b71fe4071875c878195fa24894004495744b59dfc87dc7e976f6696: " {High-throughput screening aga ... "
# WARNING Missing Expected Field 'booktitle' from entry Powell2018: " Bexarotene ? A novel modulator ... "
# WARNING Missing Expected Field 'booktitle' from entry Powell2017: " HNF1B loss exacerbates the dev ... "
# WARNING Missing Expected Field 'booktitle' from entry Powell2016: " Dual Chromatin and Cytoskeleta ... "
# WARNING Missing Expected Field 'booktitle' from entry Powell2015: " ATM functions at the peroxisom ... "
# WARNING Missing Expected Field 'booktitle' from entry Powell2014: " Defining estrogenic mechanisms ... "
# SUCESSFULLY PARSED de_Groot_2022: " Combined inhibition of {HMGCoA} reductase and mitochondrial  ... "
# SUCESSFULLY PARSED Powell_2022: " {deepOrganoid}: A brightfield cell viability model for scree ... "
# SUCESSFULLY PARSED Shah_2021: " Mammary-specific expression of Trim24 establishes a mouse mo ... "
# SUCESSFULLY PARSED Zhao_2021: " Morphological screening of mesenchymal mammary tumor organoi ... "
# SUCESSFULLY PARSED Handley_2021: " Rational Combination of {CRM}1 Inhibitor Selinexor and Olapa ... "
# SUCESSFULLY PARSED Chowdhury_2021: " Therapeutically actionable signaling node to rescue {AURKA}  ... "
# SUCESSFULLY PARSED Bolt_2021: " Endocrine disrupting chemicals differentially alter intranuc ... "
# SUCESSFULLY PARSED Henderson_2021: " A High-Throughput Approach to Identify Effective Systemic Ag ... "
# WARNING Missing Expected Field 'journal' from entry 1a8261afcb35e975c081382a2d99e23787366d37579903bccbbaa04e3803d848: " {Pharmacologic profiling of pa ... "
# SUCESSFULLY PARSED Powell2019: " Bacteria-to-Human Protein Networks Reveal Origins of Endogen ... "
# WARNING Missing Expected Field 'journal' from entry 68611bd12b71fe4071875c878195fa24894004495744b59dfc87dc7e976f6696: " {High-throughput screening aga ... "
# SUCESSFULLY PARSED Powell2018: " Bexarotene ? A novel modulator of AURKA and the primary cili ... "
# SUCESSFULLY PARSED Powell2017: " HNF1B loss exacerbates the development of chromophobe renal  ... "
# SUCESSFULLY PARSED Powell2016: " Dual Chromatin and Cytoskeletal Remodeling by SETD2  "
# SUCESSFULLY PARSED Powell2015: " ATM functions at the peroxisome to induce pexophagy in respo ... "
# SUCESSFULLY PARSED Powell2014: " Defining estrogenic mechanisms of bisphenol A analogs throug ... "
# WARNING: repeated bibliograhpy entry: Powell2018
# WARNING: repeated bibliograhpy entry: Powell2018
# WARNING: repeated bibliograhpy entry: Powell2018
# WARNING: repeated bibliograhpy entry: Powell2017
# WARNING: repeated bibliograhpy entry: Powell2016
# WARNING: repeated bibliograhpy entry: Powell2018
# WARNING: repeated bibliograhpy entry: Powell2018
# WARNING: repeated bibliograhpy entry: Powell2018
# WARNING: repeated bibliograhpy entry: Powell2017
# WARNING: repeated bibliograhpy entry: Powell2016
